# %%
# environment widget
dbutils.widgets.text("env", "dev", "Target Environment")
ENV = dbutils.widgets.get("env")

# construct catalog.schema references
CATALOG = ENV
BRONZE_SCHEMA = f"{CATALOG}.bronze"
SILVER_SCHEMA = f"{CATALOG}.silver"
GOLD_SCHEMA = f"{CATALOG}.gold"

# volume path for landing raw files
LANDING_ZONE = f"/Volumes/{CATALOG}/bronze/landing_zone"

# source identifier
RECORD_SOURCE = "iowa_liquor_soda_api"

# print config for verification
print(f"Environment: {ENV}")
print(f"Bronze:      {BRONZE_SCHEMA}")
print(f"Silver:      {SILVER_SCHEMA}")
print(f"Gold:        {GOLD_SCHEMA}")
print(f"Landing:     {LANDING_ZONE}")
